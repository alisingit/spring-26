# %%
import numpy as np
import pandas as pd

# %%
import sklearn.datasets as ds

# %%
from source.tree import Tree

# %%
df = pd.read_csv("data/Titanic-Dataset.xls")

# %%
target = "Survived"

# %%
df["Sex"] = np.where(df["Sex"] == df["Sex"][0], 1, 0)

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
model = Tree()

# %%
x, y = df.drop(columns=[target]).to_numpy(), df[target].to_numpy()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.6, stratify=y)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, train_size=0.6, stratify=y_test)

# %%
model.fit(x_train, y_train)

# %%
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
print(accuracy_score(y_pred=model.predict(x_test), y_true=y_test))
accuracy_score(y_pred=DecisionTreeClassifier(max_depth=10, min_samples_split=5).fit(x_train, y_train).predict(x_test), y_true=y_test)
# Out:
# 0.7762237762237763
# 0.7972027972027972

# %%
model.prune(x_val, y_val)

# %%
print(accuracy_score(y_pred=model.predict(x_test), y_true=y_test))
# Out:
# 0.7852447552447552
